# %% [markdown]
# # **MLP with extended physics loss function (Option 1: with PDEs numeric approximation)**

# %% [markdown]
# ## **Running the models using the 'modelling' package**
#
# A notebook through which different modelling configurations can be ran, using the ``modelling`` package. It follows the steps of:
# - preparing packages;
# - setting "global" variables;
# - getting the data;
# - defining hyperparameters;
# - running a grid search and/or training a model; and
# - evaluation.
# In the modelling package, variations can be made to the models and training functions to experiment. Don't forget to restart the notebook after making changes there.

# %% [markdown]
# For loading models, go to the ``src/results/models``:
# - Baseline NO2 2017 with MLP and MSE loss: ``best_mlp_no2_baseline.pth``
# - Exp 1: NO2 2017 with MLP and option 1 simple physics loss: ``best_mlp_no2_adjusted_dist.pth`` (naming because I updated the distance between T and B)

# %%
print("Starting script...")


from modelling.MLP import BasicMLP
from modelling import *


import optuna
import threading
import os
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import ConcatDataset
# Out:
# Starting script...
#
# Running __init__.py for data pipeline...
# Modelling package initialized

# %% [markdown]
# Use GPU when available

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("Device: ", device)
# Out:
# Device:  cpu

# %% [markdown]
# ### **Set "global" variables**

# %%
Path.cwd()
# Out:
# PosixPath('/home/rachel/forecasting_smog_PEML/src')

# %%
HABROK = bool(0)                  # set to True if using HABROK; it will print
                                  # all stdout to a .txt file to log progress

BASE_DIR = Path.cwd().parents[0] # set it to the root directory of the project, not src
MODEL_PATH = BASE_DIR /"src" / "results" / "models"
MINMAX_PATH = BASE_DIR  / "data" / "data_combined" / "pollutants_minmax.csv"

print("BASE_DIR: ", BASE_DIR)
print("MODEL_PATH: ", MODEL_PATH)
print("MINMAX_PATH: ", MINMAX_PATH)

torch.manual_seed(34)             # set seed for reproducibility

N_HOURS_U = 24 * 3               # number of hours to use for input (number of days * 24 hours)
N_HOURS_Y = 24                    # number of hours to predict (1 day * 24 hours)
N_HOURS_STEP = 24                 # "sampling rate" in hours of the data; e.g. 24 
                                  # means sample an I/O-pair every 24 hours
                                  # the contaminants and meteorological vars

# Change this according to the data you want to use
YEARS = [2017]
TRAIN_YEARS = [2017]
VAL_YEARS = [2017]
TEST_YEARS = [2017]

LOSS_FUNC = "Physics_PDE" # choose from "MSE" and "Physics_Linear_MSE" and "Physics_PDE"
# Out:
# BASE_DIR:  /home/rachel/forecasting_smog_PEML
# MODEL_PATH:  /home/rachel/forecasting_smog_PEML/src/results/models
# MINMAX_PATH:  /home/rachel/forecasting_smog_PEML/data/data_combined/pollutants_minmax.csv

# %% [markdown]
# ### **Load in data and create PyTorch *Datasets***

# %%
# Load in data and create PyTorch Datasets. To tune
# which exact .csv files get extracted, change the
# lists in the get_dataframes() definition

train_input_frames = get_dataframes('train', 'u', YEARS)
train_output_frames = get_dataframes('train', 'y', YEARS)

val_input_frames = get_dataframes('val', 'u', YEARS)
val_output_frames = get_dataframes('val', 'y', YEARS)

test_input_frames = get_dataframes('test', 'u', YEARS)
test_output_frames = get_dataframes('test', 'y', YEARS) 

print("Successfully loaded data")
# Out:
# Imported train_2017_combined_u.csv
# Imported train_2017_combined_y.csv
# Imported val_2017_combined_u.csv
# Imported val_2017_combined_y.csv
# Imported test_2017_combined_u.csv
# Imported test_2017_combined_y.csv
# Successfully loaded data

# %%
train_dataset = TimeSeriesDataset(
    train_input_frames,  # list of input training dataframes
    train_output_frames, # list of output training dataframes
    len(TRAIN_YEARS),                   # number of dataframes put in for both
                         # (basically len(train_input_frames) and
                         # len(train_output_frames) must be equal)
    N_HOURS_U,           # number of hours of input data
    N_HOURS_Y,           # number of hours of output data
    N_HOURS_STEP,        # number of hours between each input/output pair
)
val_dataset = TimeSeriesDataset(
    val_input_frames,    # etc.
    val_output_frames,
    len(VAL_YEARS),
    N_HOURS_U,
    N_HOURS_Y,
    N_HOURS_STEP,
)
test_dataset = TimeSeriesDataset(
    test_input_frames,
    test_output_frames,
    len(TEST_YEARS),
    N_HOURS_U,
    N_HOURS_Y,
    N_HOURS_STEP,
)

del train_input_frames, train_output_frames
del val_input_frames, val_output_frames
del test_input_frames, test_output_frames

# %%
train_dataset.u
# Out:
# [                           DD   FF        FH        FX       NO2         P  \
#  DateTime
#  2017-08-01 00:00:00  0.166667  0.1  0.111111  0.000000  0.242115  0.562982
#  2017-08-01 01:00:00  0.000000  0.0  0.111111  0.052632  0.223158  0.570694
#  2017-08-01 02:00:00  0.000000  0.0  0.000000  0.000000  0.165911  0.560411
#  2017-08-01 03:00:00  0.277778  0.1  0.000000  0.000000  0.142363  0.555270
#  2017-08-01 04:00:00  0.805556  0.2  0.111111  0.105263  0.156297  0.555270
#  ...                       ...  ...       ...       ...       ...       ...
#  2017-11-16 19:00:00  0.750000  0.2  0.333333  0.210526  0.523871  0.789203
#  2017-11-16 20:00:00  0.972222  0.3  0.333333  0.421053  0.512314  0.814910
#  2017-11-16 21:00:00  0.888889  0.1  0.222222  0.263158  0.232880  0.827763
#  2017-11-16 22:00:00  0.944444  0.2  0.111111  0.105263  0.108123  0.832905
#  2017-11-16 23:00:00  0.861111  0.1  0.222222  0.105263  0.205120  0.845758
#
#                        SQ         T        TD
#  DateTime
#  2017-08-01 00:00:00  0.0  0.536667  0.726852
#  2017-08-01 01:00:00  0.0  0.546667  0.740741
#  2017-08-01 02:00:00  0.0  0.506667  0.689815
#  2017-08-01 03:00:00  0.0  0.463333  0.634259
#  2017-08-01 04:00:00  0.0  0.493333  0.662037
#  ...                  ...       ...       ...
#  2017-11-16 19:00:00  0.0  0.390000  0.513889
#  2017-11-16 20:00:00  0.0  0.353333  0.462963
#  2017-11-16 21:00:00  0.0  0.330000  0.435185
#  2017-11-16 22:00:00  0.0  0.306667  0.407407
#  2017-11-16 23:00:00  0.0  0.250000  0.319444
#
#  [2592 rows x 9 columns]]

# %%
train_dataset.y
# Out:
# [                          NO2
#  DateTime
#  2017-08-01 00:00:00  0.223698
#  2017-08-01 01:00:00  0.145496
#  2017-08-01 02:00:00  0.275978
#  2017-08-01 03:00:00  0.423742
#  2017-08-01 04:00:00  0.478721
#  ...                       ...
#  2017-11-16 19:00:00  0.606502
#  2017-11-16 20:00:00  0.456470
#  2017-11-16 21:00:00  0.483258
#  2017-11-16 22:00:00  0.468784
#  2017-11-16 23:00:00  0.473428
#
#  [2592 rows x 1 columns]]

# %%
len(train_dataset.pairs[0][0])
# Out:
# 72

# %%
train_dataset.pairs[0][0]
# Out:
# tensor([[0.1667, 0.1000, 0.1111, 0.0000, 0.2421, 0.5630, 0.0000, 0.5367, 0.7269],
#         [0.0000, 0.0000, 0.1111, 0.0526, 0.2232, 0.5707, 0.0000, 0.5467, 0.7407],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.1659, 0.5604, 0.0000, 0.5067, 0.6898],
#         [0.2778, 0.1000, 0.0000, 0.0000, 0.1424, 0.5553, 0.0000, 0.4633, 0.6343],
#         [0.8056, 0.2000, 0.1111, 0.1053, 0.1563, 0.5553, 0.0000, 0.4933, 0.6620],
#         [0.0000, 0.0000, 0.1111, 0.1053, 0.3135, 0.5681, 0.3000, 0.6200, 0.7593],
#         [0.7222, 0.1000, 0.1111, 0.0526, 0.5326, 0.5913, 0.0000, 0.6433, 0.7269],
#         [0.7500, 0.1000, 0.1111, 0.1053, 0.5367, 0.5938, 0.0000, 0.6500, 0.7037],
#         [0.7222, 0.2000, 0.2222, 0.1053, 0.5172, 0.5964, 0.0000, 0.6733, 0.6574],
#         [0.7500, 0.2000, 0.2222, 0.2105, 0.4459, 0.5990, 0.3000, 0.7133, 0.6157],
#         [0.6111, 0.2000, 0.2222, 0.1579, 0.3129, 0.6041, 0.0000, 0.7167, 0.6019],
#         [0.6111, 0.2000, 0.2222, 0.1579, 0.3478, 0.6067, 0.0000, 0.7133, 0.5926],
#         [0.6528, 0.1000, 0.2222, 0.1053, 0.3649, 0.6041, 0.2000, 0.7800, 0.6435],
#         [0.6944, 0.2000, 0.2222, 0.1053, 0.3019, 0.6015, 0.2000, 0.7867, 0.4861],
#         [0.7222, 0.2000, 0.2222, 0.2105, 0.2268, 0.5990, 0.4000, 0.7733, 0.5046],
#         [0.6111, 0.2000, 0.2222, 0.1579, 0.2246, 0.6015, 0.1000, 0.7633, 0.5972],
#         [0.6944, 0.2000, 0.2222, 0.2105, 0.2855, 0.6041, 0.7000, 0.7700, 0.5880],
#         [0.5833, 0.2000, 0.2222, 0.1579, 0.2469, 0.6015, 0.2000, 0.7267, 0.6435],
#         [0.7222, 0.2000, 0.2222, 0.1579, 0.2171, 0.6144, 0.2000, 0.6967, 0.6944],
#         [0.6944, 0.1000, 0.1111, 0.1053, 0.2834, 0.6298, 0.0000, 0.5933, 0.7130],
#         [0.4167, 0.1000, 0.1111, 0.0526, 0.3918, 0.6298, 0.0000, 0.5267, 0.6944],
#         [0.4722, 0.1000, 0.1111, 0.0000, 0.4752, 0.6375, 0.0000, 0.5200, 0.6991],
#         [0.4722, 0.1000, 0.1111, 0.0526, 0.5745, 0.6298, 0.0000, 0.5067, 0.6852],
#         [0.5000, 0.1000, 0.1111, 0.1053, 0.5891, 0.6247, 0.0000, 0.5033, 0.6713],
#         [0.0000, 0.0000, 0.1111, 0.0526, 0.5491, 0.6298, 0.0000, 0.5000, 0.6806],
#         [0.4444, 0.1000, 0.1111, 0.0526, 0.5092, 0.6221, 0.0000, 0.5300, 0.6944],
#         [0.4167, 0.2000, 0.1111, 0.0526, 0.3212, 0.6144, 0.0000, 0.5267, 0.6898],
#         [0.3889, 0.1000, 0.2222, 0.1053, 0.2835, 0.6118, 0.0000, 0.5467, 0.6898],
#         [0.5000, 0.1000, 0.1111, 0.0526, 0.4099, 0.6144, 0.0000, 0.5533, 0.7083],
#         [0.5833, 0.2000, 0.2222, 0.1579, 0.4797, 0.6272, 0.0000, 0.6067, 0.7083],
#         [0.6389, 0.2000, 0.2222, 0.2105, 0.5086, 0.6272, 0.0000, 0.6333, 0.6991],
#         [0.6667, 0.4000, 0.3333, 0.2632, 0.4155, 0.6375, 0.0000, 0.6567, 0.6574],
#         [0.6667, 0.4000, 0.4444, 0.3158, 0.3375, 0.6478, 0.1000, 0.6800, 0.6574],
#         [0.6389, 0.3000, 0.3333, 0.3684, 0.2610, 0.6478, 0.1000, 0.7067, 0.6713],
#         [0.5556, 0.4000, 0.4444, 0.2632, 0.2420, 0.6555, 0.3000, 0.7300, 0.6296],
#         [0.5833, 0.4000, 0.4444, 0.3158, 0.2146, 0.6427, 0.2000, 0.7433, 0.5741],
#         [0.5556, 0.3000, 0.3333, 0.2632, 0.1782, 0.6221, 0.1000, 0.7600, 0.5370],
#         [0.5000, 0.4000, 0.4444, 0.2632, 0.1985, 0.6195, 0.0000, 0.7533, 0.5556],
#         [0.5000, 0.5000, 0.4444, 0.3684, 0.2416, 0.5964, 0.0000, 0.7600, 0.6204],
#         [0.5833, 0.5000, 0.4444, 0.4737, 0.2883, 0.5938, 0.0000, 0.7267, 0.5833],
#         [0.5833, 0.4000, 0.7778, 0.5789, 0.2718, 0.6093, 0.0000, 0.5933, 0.6806],
#         [0.5556, 0.2000, 0.3333, 0.3158, 0.1936, 0.5964, 0.0000, 0.5600, 0.7083],
#         [0.4861, 0.1000, 0.1111, 0.1579, 0.2238, 0.5835, 0.0000, 0.5533, 0.7361],
#         [0.4167, 0.2000, 0.2222, 0.1579, 0.2430, 0.5656, 0.0000, 0.5533, 0.7269],
#         [0.3889, 0.2000, 0.2222, 0.1579, 0.3154, 0.5681, 0.0000, 0.5567, 0.7315],
#         [0.4444, 0.3000, 0.2222, 0.1579, 0.2860, 0.5553, 0.0000, 0.5800, 0.7639],
#         [0.5000, 0.3000, 0.3333, 0.2632, 0.2077, 0.5373, 0.0000, 0.5967, 0.7778],
#         [0.5000, 0.2000, 0.2222, 0.2105, 0.1640, 0.5167, 0.0000, 0.6000, 0.7778],
#         [0.4444, 0.3000, 0.3333, 0.2632, 0.1525, 0.4961, 0.0000, 0.5967, 0.7824],
#         [0.4722, 0.4000, 0.3333, 0.3158, 0.1328, 0.4730, 0.0000, 0.6000, 0.7824],
#         [0.5000, 0.4000, 0.4444, 0.3158, 0.1252, 0.4422, 0.0000, 0.6100, 0.7639],
#         [0.4722, 0.2000, 0.3333, 0.2632, 0.1161, 0.4293, 0.0000, 0.6000, 0.7639],
#         [0.4722, 0.2000, 0.2222, 0.1579, 0.1766, 0.4165, 0.0000, 0.5967, 0.7731],
#         [0.5556, 0.4000, 0.3333, 0.3158, 0.2840, 0.4139, 0.0000, 0.6533, 0.8056],
#         [0.5833, 0.5000, 0.4444, 0.4211, 0.3435, 0.4010, 0.5000, 0.6967, 0.8009],
#         [0.5833, 0.6000, 0.5556, 0.4737, 0.3057, 0.3985, 0.0000, 0.6867, 0.8194],
#         [0.5833, 0.6000, 0.5556, 0.4737, 0.2615, 0.4036, 0.0000, 0.6633, 0.8519],
#         [0.6389, 0.5000, 0.6667, 0.5789, 0.2453, 0.4190, 0.0000, 0.6133, 0.7454],
#         [0.6389, 0.7000, 0.7778, 0.6316, 0.1434, 0.4216, 0.6000, 0.7067, 0.6806],
#         [0.6667, 0.9000, 0.8889, 0.7368, 0.1046, 0.4267, 0.7000, 0.7467, 0.6435],
#         [0.6667, 0.8000, 0.7778, 0.7368, 0.0607, 0.4319, 0.8000, 0.7667, 0.6019],
#         [0.6667, 0.9000, 1.0000, 0.8947, 0.0700, 0.4319, 1.0000, 0.7867, 0.6065],
#         [0.6944, 0.8000, 0.8889, 0.7895, 0.0594, 0.4422, 0.4000, 0.7400, 0.6389],
#         [0.6667, 0.8000, 0.7778, 0.6842, 0.0823, 0.4370, 0.5000, 0.7633, 0.6389],
#         [0.6667, 0.7000, 0.8889, 0.7368, 0.1016, 0.4473, 1.0000, 0.7467, 0.6944],
#         [0.6389, 0.9000, 0.8889, 0.8421, 0.1005, 0.4550, 0.5000, 0.7067, 0.5278],
#         [0.6667, 0.7000, 1.0000, 0.8947, 0.0701, 0.4627, 0.3000, 0.6900, 0.5602],
#         [0.6389, 1.0000, 0.8889, 0.9474, 0.0572, 0.4653, 0.0000, 0.6800, 0.5648],
#         [0.6667, 0.9000, 0.8889, 0.8421, 0.0533, 0.4627, 0.0000, 0.6567, 0.5741],
#         [0.6667, 0.7000, 0.7778, 0.7368, 0.0475, 0.4627, 0.0000, 0.6300, 0.6019],
#         [0.6389, 0.4000, 0.5556, 0.5789, 0.0376, 0.4576, 0.0000, 0.6100, 0.6204],
#         [0.6111, 0.5000, 0.4444, 0.4211, 0.0373, 0.4499, 0.0000, 0.5933, 0.6296]])

# %%
train_dataset.pairs[0][1]
# Out:
# tensor([[0.1965],
#         [0.1501],
#         [0.1518],
#         [0.2622],
#         [0.5524],
#         [0.4840],
#         [0.3544],
#         [0.2754],
#         [0.1948],
#         [0.1734],
#         [0.1505],
#         [0.1352],
#         [0.0778],
#         [0.1184],
#         [0.1293],
#         [0.1238],
#         [0.1043],
#         [0.0997],
#         [0.0812],
#         [0.0823],
#         [0.1155],
#         [0.0837],
#         [0.0570],
#         [0.1006]])

# %%
# Assuming train_dataset.u[0] is a pandas Index object with column names
column_names = list(train_dataset.u[0])  # Convert Index to list

# Now, find the indices of the columns 'NO2', 'DD', 'FH'
no2_idx = column_names.index('NO2')
dd_idx = column_names.index('DD')
fh_idx = column_names.index('FH')

print("NO2 index: ", no2_idx)
print("DD index (wind direction): ", dd_idx)
print("FH index (Hourly wind speed): ", fh_idx)
# Out:
# NO2 index:  4
# DD index (wind direction):  0
# FH index (Hourly wind speed):  2

# %%
train_dataset.u[0].iloc[:,no2_idx]
# Out:
# DateTime
# 2017-08-01 00:00:00    0.242115
# 2017-08-01 01:00:00    0.223158
# 2017-08-01 02:00:00    0.165911
# 2017-08-01 03:00:00    0.142363
# 2017-08-01 04:00:00    0.156297
#                          ...
# 2017-11-16 19:00:00    0.523871
# 2017-11-16 20:00:00    0.512314
# 2017-11-16 21:00:00    0.232880
# 2017-11-16 22:00:00    0.108123
# 2017-11-16 23:00:00    0.205120
# Name: NO2, Length: 2592, dtype: float64

# %%
train_dataset.u[0].iloc[:,dd_idx]
# Out:
# DateTime
# 2017-08-01 00:00:00    0.166667
# 2017-08-01 01:00:00    0.000000
# 2017-08-01 02:00:00    0.000000
# 2017-08-01 03:00:00    0.277778
# 2017-08-01 04:00:00    0.805556
#                          ...
# 2017-11-16 19:00:00    0.750000
# 2017-11-16 20:00:00    0.972222
# 2017-11-16 21:00:00    0.888889
# 2017-11-16 22:00:00    0.944444
# 2017-11-16 23:00:00    0.861111
# Name: DD, Length: 2592, dtype: float64

# %%
train_dataset.u[0].iloc[:,fh_idx]
# Out:
# DateTime
# 2017-08-01 00:00:00    0.111111
# 2017-08-01 01:00:00    0.111111
# 2017-08-01 02:00:00    0.000000
# 2017-08-01 03:00:00    0.000000
# 2017-08-01 04:00:00    0.111111
#                          ...
# 2017-11-16 19:00:00    0.333333
# 2017-11-16 20:00:00    0.333333
# 2017-11-16 21:00:00    0.222222
# 2017-11-16 22:00:00    0.111111
# 2017-11-16 23:00:00    0.222222
# Name: FH, Length: 2592, dtype: float64

# %% [markdown]
# ## **Computing y with the y_phy**

# %%
# import matplotlib.pyplot as plt
# # Define basic training
# # Create train & validation loaders (following the original code)
# n_hidden_layers = 2
# n_hidden_units = 64
# batch_size = 32
# lr = 1e-5
# weight_decay = 1e-4

# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# # Initialize MLP model
# model = BasicMLP(
#     N_INPUT_UNITS=train_dataset.__n_features_in__(),
#     N_HIDDEN_LAYERS=n_hidden_layers,
#     N_HIDDEN_UNITS=n_hidden_units,
#     N_OUTPUT_UNITS=train_dataset.__n_features_out__(),
#     loss_function=LOSS_FUNC,
# )

# # After training, we can plot y_phy vs y_pred for both training and validation data
# _, train_losses, val_losses, all_y_phy_train, all_y_pred_train, all_y_phy_val, all_y_pred_val = model.train_model(train_loader, val_loader, epochs=50, lr=lr, weight_decay=weight_decay, device=device)

# # Plot Training Loss vs Validation Loss
# epochs = range(1, len(train_losses) + 1)
# plt.figure(figsize=(8, 6))
# plt.plot(epochs, train_losses, label="Train Loss", color="blue", linestyle="-")
# plt.plot(epochs, val_losses, label="Validation Loss", color="red", linestyle="--")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.title("Training vs Validation Loss")
# plt.legend()
# plt.grid(True)
# plt.show()

# # Plot y_phy vs y_pred for training data
# plt.figure(figsize=(8, 6))
# plt.scatter(all_y_phy_train, all_y_pred_train, label="Train", alpha=0.5, color="blue")
# plt.xlabel("y_phy (True Values)")
# plt.ylabel("y_pred (Predicted Values)")
# plt.title("Training Data: y_phy vs y_pred")
# plt.legend()
# plt.grid(True)
# plt.show()

# # Plot y_phy vs y_pred for validation data
# plt.figure(figsize=(8, 6))
# plt.scatter(all_y_phy_val, all_y_pred_val, label="Validation", alpha=0.5, color="red")
# plt.xlabel("y_phy (True Values)")
# plt.ylabel("y_pred (Predicted Values)")
# plt.title("Validation Data: y_phy vs y_pred")
# plt.legend()
# plt.grid(True)
# plt.show()
# Out:
# Epoch 1/50
# Phy loss tensor(0.1145, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1349, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1349, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1247, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1465, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1465, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1293, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1499, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1499, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1407, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1744, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1744, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2544)
# MSE loss tensor(0.2366)
# total_weighted_loss tensor(0.2366)
# Epoch 1/50 - Train Loss: 0.151411 - Val Loss: 0.236646
# Epoch 2/50
# Phy loss tensor(0.0935, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1276, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1276, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1363, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1594, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1594, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1117, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1482, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1482, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2428, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1513, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1513, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2538)
# MSE loss tensor(0.2359)
# total_weighted_loss tensor(0.2360)
# Epoch 2/50 - Train Loss: 0.146645 - Val Loss: 0.235959
# Epoch 3/50
# Phy loss tensor(0.1241, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1519, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1519, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1122, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1590, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1590, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1227, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1183, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1183, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1671, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1683, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1683, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2532)
# MSE loss tensor(0.2352)
# total_weighted_loss tensor(0.2353)
# Epoch 3/50 - Train Loss: 0.149392 - Val Loss: 0.235275
# Epoch 4/50
# Phy loss tensor(0.1082, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1556, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1556, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1345, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1510, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1510, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0987, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1194, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1194, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2319, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1742, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1742, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2526)
# MSE loss tensor(0.2346)
# total_weighted_loss tensor(0.2346)
# Epoch 4/50 - Train Loss: 0.150057 - Val Loss: 0.234596
# Epoch 5/50
# Phy loss tensor(0.1155, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1385, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1385, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1133, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1339, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1339, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1441, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1472, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1472, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1004, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1927, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1927, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2520)
# MSE loss tensor(0.2339)
# total_weighted_loss tensor(0.2339)
# Epoch 5/50 - Train Loss: 0.153101 - Val Loss: 0.233924
# Epoch 6/50
# Phy loss tensor(0.1493, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1603, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1603, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1289, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1392, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1392, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0804, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1372, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1372, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1523, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1179, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1179, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2513)
# MSE loss tensor(0.2332)
# total_weighted_loss tensor(0.2333)
# Epoch 6/50 - Train Loss: 0.138641 - Val Loss: 0.233255
# Epoch 7/50
# Phy loss tensor(0.1096, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1482, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1482, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1397, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1556, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1556, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1404, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1331, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0229, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1105, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1105, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2507)
# MSE loss tensor(0.2326)
# total_weighted_loss tensor(0.2326)
# Epoch 7/50 - Train Loss: 0.136835 - Val Loss: 0.232598
# Epoch 8/50
# Phy loss tensor(0.1659, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1746, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1746, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0610, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1236, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1236, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1417, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1264, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1264, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1014, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1528, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1528, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2501)
# MSE loss tensor(0.2319)
# total_weighted_loss tensor(0.2319)
# Epoch 8/50 - Train Loss: 0.144348 - Val Loss: 0.231946
# Epoch 9/50
# Phy loss tensor(0.0710, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1236, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1236, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1787, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1448, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1448, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1167, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1660, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1660, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1047, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1065, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1066, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2496)
# MSE loss tensor(0.2313)
# total_weighted_loss tensor(0.2313)
# Epoch 9/50 - Train Loss: 0.135250 - Val Loss: 0.231298
# Epoch 10/50
# Phy loss tensor(0.0930, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1396, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1396, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1276, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1376, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1376, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1456, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1556, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1556, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1010, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1067, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1067, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2490)
# MSE loss tensor(0.2306)
# total_weighted_loss tensor(0.2307)
# Epoch 10/50 - Train Loss: 0.134867 - Val Loss: 0.230656
# Epoch 11/50
# Phy loss tensor(0.1242, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1515, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1515, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1203, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1341, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1341, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1196, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1410, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1410, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1039, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1247, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1247, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2484)
# MSE loss tensor(0.2300)
# total_weighted_loss tensor(0.2300)
# Epoch 11/50 - Train Loss: 0.137837 - Val Loss: 0.230018
# Epoch 12/50
# Phy loss tensor(0.1472, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1120, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1120, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1229, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1688, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1688, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0822, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1344, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1344, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1461, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1640, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1640, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2478)
# MSE loss tensor(0.2294)
# total_weighted_loss tensor(0.2294)
# Epoch 12/50 - Train Loss: 0.144790 - Val Loss: 0.229383
# Epoch 13/50
# Phy loss tensor(0.1219, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1486, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1486, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1537, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1460, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1460, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0935, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1245, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1245, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0734, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1415, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1415, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2472)
# MSE loss tensor(0.2287)
# total_weighted_loss tensor(0.2287)
# Epoch 13/50 - Train Loss: 0.140169 - Val Loss: 0.228742
# Epoch 14/50
# Phy loss tensor(0.1079, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1400, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1400, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1513, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1466, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1466, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1149, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1300, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1300, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0487, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1454, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1454, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2466)
# MSE loss tensor(0.2281)
# total_weighted_loss tensor(0.2281)
# Epoch 14/50 - Train Loss: 0.140490 - Val Loss: 0.228105
# Epoch 15/50
# Phy loss tensor(0.1468, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1641, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1641, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0782, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1335, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1335, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1346, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1208, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1208, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1014, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1320, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1320, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2461)
# MSE loss tensor(0.2274)
# total_weighted_loss tensor(0.2275)
# Epoch 15/50 - Train Loss: 0.137585 - Val Loss: 0.227470
# Epoch 16/50
# Phy loss tensor(0.1096, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1434, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1434, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1515, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1363, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1363, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0928, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1416, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1416, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1190, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1139, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1139, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2455)
# MSE loss tensor(0.2268)
# total_weighted_loss tensor(0.2268)
# Epoch 16/50 - Train Loss: 0.133783 - Val Loss: 0.226838
# Epoch 17/50
# Phy loss tensor(0.0830, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1180, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1180, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1618, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1412, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1412, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1135, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1417, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1417, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0962, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1888, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1888, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2449)
# MSE loss tensor(0.2262)
# total_weighted_loss tensor(0.2262)
# Epoch 17/50 - Train Loss: 0.147428 - Val Loss: 0.226213
# Epoch 18/50
# Phy loss tensor(0.1485, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1279, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1279, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0806, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1580, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1580, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0910, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1187, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1187, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2443, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1676, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1676, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2443)
# MSE loss tensor(0.2256)
# total_weighted_loss tensor(0.2256)
# Epoch 18/50 - Train Loss: 0.143055 - Val Loss: 0.225583
# Epoch 19/50
# Phy loss tensor(0.1853, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1431, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1431, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1032, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1526, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1526, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0792, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1174, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1174, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0492, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1276, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1276, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2438)
# MSE loss tensor(0.2249)
# total_weighted_loss tensor(0.2250)
# Epoch 19/50 - Train Loss: 0.135174 - Val Loss: 0.224950
# Epoch 20/50
# Phy loss tensor(0.1580, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1495, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1495, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1068, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1190, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1190, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0974, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1380, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1380, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0660, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1476, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1476, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2432)
# MSE loss tensor(0.2243)
# total_weighted_loss tensor(0.2243)
# Epoch 20/50 - Train Loss: 0.138526 - Val Loss: 0.224327
# Epoch 21/50
# Phy loss tensor(0.1357, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1579, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1579, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0827, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1117, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1117, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1320, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1424, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1424, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1081, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1193, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1193, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2426)
# MSE loss tensor(0.2237)
# total_weighted_loss tensor(0.2237)
# Epoch 21/50 - Train Loss: 0.132811 - Val Loss: 0.223708
# Epoch 22/50
# Phy loss tensor(0.1393, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1530, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1530, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0793, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1122, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1122, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1235, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1433, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1433, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1366, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1272, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1272, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2421)
# MSE loss tensor(0.2231)
# total_weighted_loss tensor(0.2231)
# Epoch 22/50 - Train Loss: 0.133915 - Val Loss: 0.223096
# Epoch 23/50
# Phy loss tensor(0.1139, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1379, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1379, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1446, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1194, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1194, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0954, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1459, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1459, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0846, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1421, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1421, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2415)
# MSE loss tensor(0.2225)
# total_weighted_loss tensor(0.2225)
# Epoch 23/50 - Train Loss: 0.136323 - Val Loss: 0.222487
# Epoch 24/50
# Phy loss tensor(0.1202, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1588, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1588, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1191, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1090, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1090, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0869, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1428, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1428, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1904, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1060, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1060, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2409)
# MSE loss tensor(0.2219)
# total_weighted_loss tensor(0.2219)
# Epoch 24/50 - Train Loss: 0.129169 - Val Loss: 0.221879
# Epoch 25/50
# Phy loss tensor(0.1000, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1409, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1409, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1231, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1148, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1148, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1394, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1447, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1447, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0405, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1406, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1406, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2404)
# MSE loss tensor(0.2213)
# total_weighted_loss tensor(0.2213)
# Epoch 25/50 - Train Loss: 0.135271 - Val Loss: 0.221277
# Epoch 26/50
# Phy loss tensor(0.1236, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1209, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1209, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1130, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1331, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1069, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1480, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1480, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1120, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1280, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1280, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2399)
# MSE loss tensor(0.2207)
# total_weighted_loss tensor(0.2207)
# Epoch 26/50 - Train Loss: 0.132526 - Val Loss: 0.220675
# Epoch 27/50
# Phy loss tensor(0.0889, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1218, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1218, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1204, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1233, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1233, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1161, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1409, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1409, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1797, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1860, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1860, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2393)
# MSE loss tensor(0.2201)
# total_weighted_loss tensor(0.2201)
# Epoch 27/50 - Train Loss: 0.143022 - Val Loss: 0.220074
# Epoch 28/50
# Phy loss tensor(0.1318, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1213, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1213, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0990, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1392, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1392, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1239, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1346, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1346, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0574, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1441, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1441, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2388)
# MSE loss tensor(0.2194)
# total_weighted_loss tensor(0.2195)
# Epoch 28/50 - Train Loss: 0.134780 - Val Loss: 0.219466
# Epoch 29/50
# Phy loss tensor(0.1025, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1314, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1314, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0893, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1298, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1298, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1074, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1351, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1351, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2746, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1331, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2382)
# MSE loss tensor(0.2188)
# total_weighted_loss tensor(0.2189)
# Epoch 29/50 - Train Loss: 0.132345 - Val Loss: 0.218862
# Epoch 30/50
# Phy loss tensor(0.0881, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1280, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1280, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1220, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1240, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1240, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1349, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1441, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1441, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0865, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1275, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1275, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2377)
# MSE loss tensor(0.2182)
# total_weighted_loss tensor(0.2183)
# Epoch 30/50 - Train Loss: 0.130919 - Val Loss: 0.218261
# Epoch 31/50
# Phy loss tensor(0.1076, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1237, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1237, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0807, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1407, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1407, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1395, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1273, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1273, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1509, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1392, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1392, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2371)
# MSE loss tensor(0.2176)
# total_weighted_loss tensor(0.2177)
# Epoch 31/50 - Train Loss: 0.132735 - Val Loss: 0.217662
# Epoch 32/50
# Phy loss tensor(0.0834, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1241, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1241, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1297, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1459, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1459, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1218, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1233, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1233, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1182, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1267, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1267, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2366)
# MSE loss tensor(0.2170)
# total_weighted_loss tensor(0.2171)
# Epoch 32/50 - Train Loss: 0.130014 - Val Loss: 0.217064
# Epoch 33/50
# Phy loss tensor(0.1021, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1337, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1337, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0917, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1281, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1281, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1373, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1205, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1205, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1285, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1648, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1649, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2360)
# MSE loss tensor(0.2164)
# total_weighted_loss tensor(0.2165)
# Epoch 33/50 - Train Loss: 0.136796 - Val Loss: 0.216466
# Epoch 34/50
# Phy loss tensor(0.0896, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1169, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1169, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0862, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1300, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1300, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1629, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1450, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1450, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0932, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1208, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1208, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2355)
# MSE loss tensor(0.2158)
# total_weighted_loss tensor(0.2159)
# Epoch 34/50 - Train Loss: 0.128169 - Val Loss: 0.215864
# Epoch 35/50
# Phy loss tensor(0.1251, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1052, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1052, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1095, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1388, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1388, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0816, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1431, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1431, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1789, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1339, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1339, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2349)
# MSE loss tensor(0.2152)
# total_weighted_loss tensor(0.2153)
# Epoch 35/50 - Train Loss: 0.130244 - Val Loss: 0.215268
# Epoch 36/50
# Phy loss tensor(0.1246, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1473, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1473, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1249, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1263, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1263, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0934, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1262, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1262, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0676, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0772, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0772, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2344)
# MSE loss tensor(0.2146)
# total_weighted_loss tensor(0.2147)
# Epoch 36/50 - Train Loss: 0.119260 - Val Loss: 0.214672
# Epoch 37/50
# Phy loss tensor(0.0839, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1175, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1175, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1587, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1303, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1303, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0799, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1313, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1313, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1442, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1542, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1542, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2339)
# MSE loss tensor(0.2141)
# total_weighted_loss tensor(0.2141)
# Epoch 37/50 - Train Loss: 0.133317 - Val Loss: 0.214089
# Epoch 38/50
# Phy loss tensor(0.0901, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1272, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1272, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1108, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1365, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1365, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1238, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1213, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1213, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1310, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1246, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1246, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2333)
# MSE loss tensor(0.2135)
# total_weighted_loss tensor(0.2135)
# Epoch 38/50 - Train Loss: 0.127411 - Val Loss: 0.213498
# Epoch 39/50
# Phy loss tensor(0.1202, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1158, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1158, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1444, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1559, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1559, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0835, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1045, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1045, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0330, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1542, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1542, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2328)
# MSE loss tensor(0.2129)
# total_weighted_loss tensor(0.2129)
# Epoch 39/50 - Train Loss: 0.132583 - Val Loss: 0.212910
# Epoch 40/50
# Phy loss tensor(0.1081, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1269, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1269, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0779, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1113, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1113, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1543, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1463, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1463, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0595, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1151, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1151, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2323)
# MSE loss tensor(0.2123)
# total_weighted_loss tensor(0.2123)
# Epoch 40/50 - Train Loss: 0.124892 - Val Loss: 0.212322
# Epoch 41/50
# Phy loss tensor(0.0723, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1227, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1227, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0964, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1343, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1343, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1672, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1284, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1284, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0727, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1054, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1054, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2318)
# MSE loss tensor(0.2117)
# total_weighted_loss tensor(0.2117)
# Epoch 41/50 - Train Loss: 0.122716 - Val Loss: 0.211738
# Epoch 42/50
# Phy loss tensor(0.0993, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1122, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1122, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1212, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1331, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1235, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1216, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1216, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0357, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1739, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1739, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2312)
# MSE loss tensor(0.2111)
# total_weighted_loss tensor(0.2112)
# Epoch 42/50 - Train Loss: 0.135190 - Val Loss: 0.211155
# Epoch 43/50
# Phy loss tensor(0.0710, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1130, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1130, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1234, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1235, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1235, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1362, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1403, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1404, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0851, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1278, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1278, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2307)
# MSE loss tensor(0.2105)
# total_weighted_loss tensor(0.2106)
# Epoch 43/50 - Train Loss: 0.126177 - Val Loss: 0.210563
# Epoch 44/50
# Phy loss tensor(0.1322, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1083, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1083, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1285, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1628, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1628, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0798, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1107, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1107, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0407, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1025, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1025, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2302)
# MSE loss tensor(0.2099)
# total_weighted_loss tensor(0.2100)
# Epoch 44/50 - Train Loss: 0.121077 - Val Loss: 0.209972
# Epoch 45/50
# Phy loss tensor(0.1112, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1272, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1272, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1311, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1441, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1441, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1009, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1119, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1119, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0258, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0910, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0910, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2296)
# MSE loss tensor(0.2094)
# total_weighted_loss tensor(0.2094)
# Epoch 45/50 - Train Loss: 0.118559 - Val Loss: 0.209387
# Epoch 46/50
# Phy loss tensor(0.1015, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1290, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1290, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1040, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1244, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1244, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1355, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1230, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1230, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0298, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1125, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2291)
# MSE loss tensor(0.2088)
# total_weighted_loss tensor(0.2088)
# Epoch 46/50 - Train Loss: 0.122232 - Val Loss: 0.208808
# Epoch 47/50
# Phy loss tensor(0.0863, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1118, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1118, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1029, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1143, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1143, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0922, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1469, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1469, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2638, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1203, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1203, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2286)
# MSE loss tensor(0.2082)
# total_weighted_loss tensor(0.2082)
# Epoch 47/50 - Train Loss: 0.123338 - Val Loss: 0.208230
# Epoch 48/50
# Phy loss tensor(0.0786, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0972, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0972, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1039, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1306, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1306, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1242, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1398, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1398, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1577, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1361, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1361, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2281)
# MSE loss tensor(0.2076)
# total_weighted_loss tensor(0.2076)
# Epoch 48/50 - Train Loss: 0.125937 - Val Loss: 0.207646
# Epoch 49/50
# Phy loss tensor(0.0717, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1136, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1136, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1059, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1018, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1018, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1262, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1509, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1509, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1653, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1359, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1359, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2275)
# MSE loss tensor(0.2070)
# total_weighted_loss tensor(0.2071)
# Epoch 49/50 - Train Loss: 0.125543 - Val Loss: 0.207057
# Epoch 50/50
# Phy loss tensor(0.1176, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1310, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1310, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0666, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1374, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1374, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1426, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0989, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0989, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0692, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1260, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1260, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2270)
# MSE loss tensor(0.2064)
# total_weighted_loss tensor(0.2065)
# Epoch 50/50 - Train Loss: 0.123340 - Val Loss: 0.206460

# %%
# # Create the DataLoader for the test dataset
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# # Evaluate the model on the test dataset
# df_minmax = pd.read_csv(MINMAX_PATH, sep=';')
# min_value = df_minmax["min"].values
# max_value = df_minmax["max"].values
# mse, rmse_val, smape_val = model.test_model(test_loader, min_value=min_value, max_value=max_value, device="cpu")
# Out:
# Test MSE Loss: 1733.557332
# Test RMSE Loss: 41.636010
# Test SMAPE Loss: 187.501498%

# %%
# import torch
# import matplotlib.pyplot as plt

# # Ensure the model is in evaluation mode
# model.eval()

# y_preds = []
# y_trues = []

# # Iterate through the test set and collect predictions & ground truth
# with torch.no_grad():
#     for batch in test_loader:
#         x_test, y_true = batch  # Get input and ground truth
#         x_test = x_test.to("cpu")  # Ensure data is on CPU if needed

#         # Get predictions
#         y_pred = model(x_test)

#         # Store results
#         y_preds.append(y_pred.cpu())
#         y_trues.append(y_true.cpu())

# # Convert lists to tensors
# y_preds = torch.cat(y_preds, dim=0).numpy()
# y_trues = torch.cat(y_trues, dim=0).numpy()

# # Plot results
# plt.figure(figsize=(10, 5))
# plt.plot(y_trues.flatten(), label="Ground Truth (NO₂)", linestyle="-", color="blue")
# plt.scatter(range(len(y_preds.flatten())), y_preds.flatten(), label="Predictions", color="black", s=10)

# plt.xlabel("Time Step")
# plt.ylabel("NO₂ Level")
# plt.title("Predictions vs. Ground Truth")
# plt.legend()
# plt.show()

# %% [markdown]
# ### **Start hyperparameter searching with Optuna**

# %%
def objective(trial):
    # Define hyperparameters to search over
    n_hidden_layers = trial.suggest_int("n_hidden_layers", 1, 5)
    n_hidden_units = trial.suggest_int("n_hidden_units", 32, 256)
    lr = trial.suggest_loguniform("lr", 1e-5, 1e-2)
    weight_decay = trial.suggest_loguniform("weight_decay", 1e-8, 1e-3)
    batch_size = trial.suggest_categorical("batch_size", [8, 16, 32, 64])  # Match the original hp['batch_sz']
    lambda_phy = trial.suggest_loguniform("lambda_phy", 1e-5, 1e-1)

    # Create train & validation loaders (following the original code)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Initialize MLP model
    model = BasicMLP(
        N_INPUT_UNITS=train_dataset.__n_features_in__(),
        N_HIDDEN_LAYERS=n_hidden_layers,
        N_HIDDEN_UNITS=n_hidden_units,
        N_OUTPUT_UNITS=train_dataset.__n_features_out__(),
        loss_function=LOSS_FUNC,
    )

    # Train and return validation loss
    val_loss = model.train_model(train_loader, val_loader, epochs=50, lr=lr, weight_decay=weight_decay, lambda_phy = lambda_phy, device=device)
    
    return val_loss


# Run Optuna optimization
study = optuna.create_study(direction="minimize", study_name="mlp_hyperparameter_optimization_phy_pde1", storage="sqlite:///mlp_hyperparameter_optimization_phy_pde.db", load_if_exists=True)

study.optimize(objective, n_trials=100)

# Print best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# %%
# best params for the physics model in previous studies
# remove if retune
# best_params = {'n_hidden_layers': 2, 'n_hidden_units': 237, 'lr': 0.004360166659287016, 'weight_decay': 5.881374833423609e-08, 'batch_size': 16}
best_params
# Out:
# {'n_hidden_layers': 2,
#  'n_hidden_units': 237,
#  'lr': 0.004360166659287016,
#  'weight_decay': 5.881374833423609e-08,
#  'batch_size': 16}

# %%
# Train the model with the best hyperparameters
best_model = BasicMLP(
    N_INPUT_UNITS=train_dataset.__n_features_in__(),
    N_HIDDEN_LAYERS=best_params["n_hidden_layers"],
    N_HIDDEN_UNITS=best_params["n_hidden_units"],
    N_OUTPUT_UNITS=train_dataset.__n_features_out__(),
    loss_function=LOSS_FUNC,
)

# Create train & validation loaders with the best batch size
train_loader = DataLoader(train_dataset, batch_size=best_params["batch_size"], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_params["batch_size"], shuffle=False)

# Train the model
best_model.train_model(train_loader, val_loader, epochs=50, lr=best_params["lr"], weight_decay=best_params["weight_decay"], device=device)

# Save the trained model
torch.save(best_model.state_dict(), f"{MODEL_PATH}/best_mlp_no2_pde_numerical.pth")
print("Model saved asbest_mlp_no2_pde_numerical.pth in Model folder")
# Out:
# Epoch 1/50 - Train Loss: 0.068529 - Val Loss: 0.067292
# Epoch 2/50 - Train Loss: 0.043031 - Val Loss: 0.089617
# Epoch 3/50 - Train Loss: 0.037203 - Val Loss: 0.071924
# Epoch 4/50 - Train Loss: 0.038949 - Val Loss: 0.046050
# Epoch 5/50 - Train Loss: 0.033820 - Val Loss: 0.047601
# Epoch 6/50 - Train Loss: 0.033625 - Val Loss: 0.061231
# Epoch 7/50 - Train Loss: 0.035570 - Val Loss: 0.046728
# Epoch 8/50 - Train Loss: 0.036929 - Val Loss: 0.047170
# Epoch 9/50 - Train Loss: 0.032583 - Val Loss: 0.050686
# Epoch 10/50 - Train Loss: 0.033732 - Val Loss: 0.044899
# Epoch 11/50 - Train Loss: 0.029680 - Val Loss: 0.047724
# Epoch 12/50 - Train Loss: 0.033290 - Val Loss: 0.050238
# Epoch 13/50 - Train Loss: 0.030613 - Val Loss: 0.048486
# Epoch 14/50 - Train Loss: 0.033094 - Val Loss: 0.044320
# Epoch 15/50 - Train Loss: 0.035775 - Val Loss: 0.052647
# Epoch 16/50 - Train Loss: 0.035374 - Val Loss: 0.048271
# Epoch 17/50 - Train Loss: 0.031155 - Val Loss: 0.048400
# Epoch 18/50 - Train Loss: 0.027713 - Val Loss: 0.047667
# Epoch 19/50 - Train Loss: 0.031818 - Val Loss: 0.044445
# Epoch 20/50 - Train Loss: 0.032363 - Val Loss: 0.044227
# Epoch 21/50 - Train Loss: 0.031540 - Val Loss: 0.047963
# Epoch 22/50 - Train Loss: 0.030841 - Val Loss: 0.047635
# Epoch 23/50 - Train Loss: 0.029854 - Val Loss: 0.045687
# Epoch 24/50 - Train Loss: 0.032791 - Val Loss: 0.043955
# Epoch 25/50 - Train Loss: 0.028895 - Val Loss: 0.045222
# Epoch 26/50 - Train Loss: 0.029493 - Val Loss: 0.049873
# Epoch 27/50 - Train Loss: 0.029390 - Val Loss: 0.046058
# Epoch 28/50 - Train Loss: 0.031553 - Val Loss: 0.046780
# Epoch 29/50 - Train Loss: 0.027224 - Val Loss: 0.044435
# Epoch 30/50 - Train Loss: 0.026006 - Val Loss: 0.043836
# Epoch 31/50 - Train Loss: 0.026262 - Val Loss: 0.046738
# Epoch 32/50 - Train Loss: 0.031744 - Val Loss: 0.048851
# Epoch 33/50 - Train Loss: 0.031592 - Val Loss: 0.047208
# Epoch 34/50 - Train Loss: 0.029776 - Val Loss: 0.045882
# Epoch 35/50 - Train Loss: 0.026796 - Val Loss: 0.049781
# Epoch 36/50 - Train Loss: 0.034325 - Val Loss: 0.046836
# Epoch 37/50 - Train Loss: 0.032544 - Val Loss: 0.045586
# Epoch 38/50 - Train Loss: 0.031394 - Val Loss: 0.045632
# Epoch 39/50 - Train Loss: 0.030137 - Val Loss: 0.044380
# Epoch 40/50 - Train Loss: 0.031826 - Val Loss: 0.044751
# Epoch 41/50 - Train Loss: 0.030102 - Val Loss: 0.045713
# Epoch 42/50 - Train Loss: 0.032606 - Val Loss: 0.044501
# Epoch 43/50 - Train Loss: 0.028977 - Val Loss: 0.049220
# Epoch 44/50 - Train Loss: 0.031002 - Val Loss: 0.044629
# Epoch 45/50 - Train Loss: 0.030779 - Val Loss: 0.045517
# Epoch 46/50 - Train Loss: 0.030053 - Val Loss: 0.046944
# Epoch 47/50 - Train Loss: 0.028027 - Val Loss: 0.044724
# Epoch 48/50 - Train Loss: 0.031364 - Val Loss: 0.046909
# Epoch 49/50 - Train Loss: 0.032766 - Val Loss: 0.047157
# Epoch 50/50 - Train Loss: 0.026766 - Val Loss: 0.045195
# Model saved as best_mlp_no2.pth in Model folder

# %% [markdown]
# #### **Testing the model**

# %%
df_minmax = pd.read_csv(MINMAX_PATH, sep=';')
df_minmax
# Out:
#   Unnamed: 0   min    max
# 0        NO2  1.37  93.95

# %%
best_model.load_state_dict(torch.load(f"{MODEL_PATH}/best_mlp_no2_pde_numerical.pth"))
best_model.eval()

# Create the DataLoader for the test dataset
test_loader = DataLoader(test_dataset, batch_size=best_params["batch_size"], shuffle=False)

# Evaluate the model on the test dataset
df_minmax = pd.read_csv(MINMAX_PATH, sep=';')
min_value = df_minmax["min"].values
max_value = df_minmax["max"].values
mse, rmse_val, smape_val = best_model.test_model(test_loader, min_value=min_value, max_value=max_value, device="cpu")
# Out:
# Test MSE Loss: 248.409109
# Test RMSE Loss: 16.273734
# Test SMAPE Loss: 39.003706%

# %%
print(f"Test MSE: {mse}, Test RMSE: {rmse_val}, Test SMAPE: {smape_val}")
# Out:
# Test MSE: 248.40910929670335, Test RMSE: 16.273734426648694, Test SMAPE: 39.00370553687767

# %%
import torch
import matplotlib.pyplot as plt

# Ensure the model is in evaluation mode
best_model.eval()

y_preds = []
y_trues = []

# Iterate through the test set and collect predictions & ground truth
with torch.no_grad():
    for batch in test_loader:
        x_test, y_true = batch  # Get input and ground truth
        x_test = x_test.to("cpu")  # Ensure data is on CPU if needed

        # Get predictions
        y_pred = best_model(x_test)

        # Store results
        y_preds.append(y_pred.cpu())
        y_trues.append(y_true.cpu())

# Convert lists to tensors
y_preds = torch.cat(y_preds, dim=0).numpy()
y_trues = torch.cat(y_trues, dim=0).numpy()

# Plot results
plt.figure(figsize=(10, 5))
plt.plot(y_trues.flatten(), label="Ground Truth (NO₂)", linestyle="-", color="blue")
plt.scatter(range(len(y_preds.flatten())), y_preds.flatten(), label="Predictions", color="black", s=10)

plt.xlabel("Time Step")
plt.ylabel("NO₂ Level")
plt.title("Predictions vs. Ground Truth")
plt.legend()
plt.show()
