# %% [markdown]
# # **MLP with extended physics loss function**
# # (Option 1: with PDEs numeric approximation - Eq1: Constant advection eq)

# %% [markdown]
# ## **Running the models using the 'modelling' package**
#
# A notebook through which different modelling configurations can be ran, using the ``modelling`` package. It follows the steps of:
# - preparing packages;
# - setting "global" variables;
# - getting the data;
# - defining hyperparameters;
# - running a grid search and/or training a model; and
# - evaluation.
# In the modelling package, variations can be made to the models and training functions to experiment. Don't forget to restart the notebook after making changes there.

# %% [markdown]
# For loading models, go to the ``src/results/models``:
# - Baseline NO2 2017 with MLP and MSE loss: ``best_mlp_no2_baseline.pth``
#
# Option 1 Architecture
# - Exp 1: NO2 2017 with MLP and option 1 simple physics loss: ``best_mlp_no2_linear.pth``
# - Exp 2: NO2 2017 with MLP and option 1 pde numerical solver eq 1: ``best_mlp_no2_pde_numerical_eq1.pth``
# - Exp 3: NO2 2017 with MLP and option 1 pde numerical solver eq 2: ``best_mlp_no2_pde_numerical_eq2.pth``

# %%
import os
os.chdir('../')
os.getcwd()

# %%
print("Starting script...")


from modelling.MLP import BasicMLP
from modelling import *


import optuna
import threading
import os
from pathlib import Path
import datetime
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import ConcatDataset
# Out:
# Starting script...
#
# Running __init__.py for data pipeline...
# Modelling package initialized

# %% [markdown]
# Use GPU when available

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
print("Device: ", device)
# Out:
# Device:  cpu

# %% [markdown]
# ### **Set "global" variables**

# %%
Path.cwd()
# Out:
# PosixPath('/home/rachel/forecasting_smog_PEML/src')

# %%
HABROK = bool(0)                  # set to True if using HABROK; it will print
                                  # all stdout to a .txt file to log progress

BASE_DIR = Path.cwd().parents[0] # set it to the root directory of the project, not src
MODEL_PATH = BASE_DIR /"src" / "results" / "models"
MINMAX_PATH = BASE_DIR  / "data" / "data_combined" / "pollutants_minmax.csv"

print("BASE_DIR: ", BASE_DIR)
print("MODEL_PATH: ", MODEL_PATH)
print("MINMAX_PATH: ", MINMAX_PATH)

torch.manual_seed(34)             # set seed for reproducibility

N_HOURS_U = 24 * 3               # number of hours to use for input (number of days * 24 hours)
N_HOURS_Y = 24                    # number of hours to predict (1 day * 24 hours)
N_HOURS_STEP = 24                 # "sampling rate" in hours of the data; e.g. 24 
                                  # means sample an I/O-pair every 24 hours
                                  # the contaminants and meteorological vars

# Change this according to the data you want to use
YEARS = [2017]
TRAIN_YEARS = [2017]
VAL_YEARS = [2017]
TEST_YEARS = [2017]

LOSS_FUNC = "PDE_nmer_const" # choose from "MSE" and "Physics_Linear_MSE" and "Physics_PDE_numerical_constant"
# Out:
# BASE_DIR:  /home/rachel/forecasting_smog_PEML
# MODEL_PATH:  /home/rachel/forecasting_smog_PEML/src/results/models
# MINMAX_PATH:  /home/rachel/forecasting_smog_PEML/data/data_combined/pollutants_minmax.csv

# %% [markdown]
# ### **Load in data and create PyTorch *Datasets***

# %%
# Load in data and create PyTorch Datasets. To tune
# which exact .csv files get extracted, change the
# lists in the get_dataframes() definition

train_input_frames = get_dataframes('train', 'u', YEARS)
train_output_frames = get_dataframes('train', 'y', YEARS)

val_input_frames = get_dataframes('val', 'u', YEARS)
val_output_frames = get_dataframes('val', 'y', YEARS)

test_input_frames = get_dataframes('test', 'u', YEARS)
test_output_frames = get_dataframes('test', 'y', YEARS) 

print("Successfully loaded data")
# Out:
# Imported train_2017_combined_u.csv
# Imported train_2017_combined_y.csv
# Imported val_2017_combined_u.csv
# Imported val_2017_combined_y.csv
# Imported test_2017_combined_u.csv
# Imported test_2017_combined_y.csv
# Successfully loaded data

# %%
train_dataset = TimeSeriesDataset(
    train_input_frames,  # list of input training dataframes
    train_output_frames, # list of output training dataframes
    len(TRAIN_YEARS),                   # number of dataframes put in for both
                         # (basically len(train_input_frames) and
                         # len(train_output_frames) must be equal)
    N_HOURS_U,           # number of hours of input data
    N_HOURS_Y,           # number of hours of output data
    N_HOURS_STEP,        # number of hours between each input/output pair
)
val_dataset = TimeSeriesDataset(
    val_input_frames,    # etc.
    val_output_frames,
    len(VAL_YEARS),
    N_HOURS_U,
    N_HOURS_Y,
    N_HOURS_STEP,
)
test_dataset = TimeSeriesDataset(
    test_input_frames,
    test_output_frames,
    len(TEST_YEARS),
    N_HOURS_U,
    N_HOURS_Y,
    N_HOURS_STEP,
)

del train_input_frames, train_output_frames
del val_input_frames, val_output_frames
del test_input_frames, test_output_frames

# %%
train_dataset.u
# Out:
# [                           DD   FF        FH        FX       NO2         P  \
#  DateTime
#  2017-08-01 00:00:00  0.166667  0.1  0.111111  0.000000  0.242115  0.562982
#  2017-08-01 01:00:00  0.000000  0.0  0.111111  0.052632  0.223158  0.570694
#  2017-08-01 02:00:00  0.000000  0.0  0.000000  0.000000  0.165911  0.560411
#  2017-08-01 03:00:00  0.277778  0.1  0.000000  0.000000  0.142363  0.555270
#  2017-08-01 04:00:00  0.805556  0.2  0.111111  0.105263  0.156297  0.555270
#  ...                       ...  ...       ...       ...       ...       ...
#  2017-11-16 19:00:00  0.750000  0.2  0.333333  0.210526  0.523871  0.789203
#  2017-11-16 20:00:00  0.972222  0.3  0.333333  0.421053  0.512314  0.814910
#  2017-11-16 21:00:00  0.888889  0.1  0.222222  0.263158  0.232880  0.827763
#  2017-11-16 22:00:00  0.944444  0.2  0.111111  0.105263  0.108123  0.832905
#  2017-11-16 23:00:00  0.861111  0.1  0.222222  0.105263  0.205120  0.845758
#
#                        SQ         T        TD
#  DateTime
#  2017-08-01 00:00:00  0.0  0.536667  0.726852
#  2017-08-01 01:00:00  0.0  0.546667  0.740741
#  2017-08-01 02:00:00  0.0  0.506667  0.689815
#  2017-08-01 03:00:00  0.0  0.463333  0.634259
#  2017-08-01 04:00:00  0.0  0.493333  0.662037
#  ...                  ...       ...       ...
#  2017-11-16 19:00:00  0.0  0.390000  0.513889
#  2017-11-16 20:00:00  0.0  0.353333  0.462963
#  2017-11-16 21:00:00  0.0  0.330000  0.435185
#  2017-11-16 22:00:00  0.0  0.306667  0.407407
#  2017-11-16 23:00:00  0.0  0.250000  0.319444
#
#  [2592 rows x 9 columns]]

# %%
train_dataset.y
# Out:
# [                          NO2
#  DateTime
#  2017-08-01 00:00:00  0.223698
#  2017-08-01 01:00:00  0.145496
#  2017-08-01 02:00:00  0.275978
#  2017-08-01 03:00:00  0.423742
#  2017-08-01 04:00:00  0.478721
#  ...                       ...
#  2017-11-16 19:00:00  0.606502
#  2017-11-16 20:00:00  0.456470
#  2017-11-16 21:00:00  0.483258
#  2017-11-16 22:00:00  0.468784
#  2017-11-16 23:00:00  0.473428
#
#  [2592 rows x 1 columns]]

# %%
len(train_dataset.pairs[0][0])
# Out:
# 72

# %%
train_dataset.pairs[0][0]
# Out:
# tensor([[0.1667, 0.1000, 0.1111, 0.0000, 0.2421, 0.5630, 0.0000, 0.5367, 0.7269],
#         [0.0000, 0.0000, 0.1111, 0.0526, 0.2232, 0.5707, 0.0000, 0.5467, 0.7407],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.1659, 0.5604, 0.0000, 0.5067, 0.6898],
#         [0.2778, 0.1000, 0.0000, 0.0000, 0.1424, 0.5553, 0.0000, 0.4633, 0.6343],
#         [0.8056, 0.2000, 0.1111, 0.1053, 0.1563, 0.5553, 0.0000, 0.4933, 0.6620],
#         [0.0000, 0.0000, 0.1111, 0.1053, 0.3135, 0.5681, 0.3000, 0.6200, 0.7593],
#         [0.7222, 0.1000, 0.1111, 0.0526, 0.5326, 0.5913, 0.0000, 0.6433, 0.7269],
#         [0.7500, 0.1000, 0.1111, 0.1053, 0.5367, 0.5938, 0.0000, 0.6500, 0.7037],
#         [0.7222, 0.2000, 0.2222, 0.1053, 0.5172, 0.5964, 0.0000, 0.6733, 0.6574],
#         [0.7500, 0.2000, 0.2222, 0.2105, 0.4459, 0.5990, 0.3000, 0.7133, 0.6157],
#         [0.6111, 0.2000, 0.2222, 0.1579, 0.3129, 0.6041, 0.0000, 0.7167, 0.6019],
#         [0.6111, 0.2000, 0.2222, 0.1579, 0.3478, 0.6067, 0.0000, 0.7133, 0.5926],
#         [0.6528, 0.1000, 0.2222, 0.1053, 0.3649, 0.6041, 0.2000, 0.7800, 0.6435],
#         [0.6944, 0.2000, 0.2222, 0.1053, 0.3019, 0.6015, 0.2000, 0.7867, 0.4861],
#         [0.7222, 0.2000, 0.2222, 0.2105, 0.2268, 0.5990, 0.4000, 0.7733, 0.5046],
#         [0.6111, 0.2000, 0.2222, 0.1579, 0.2246, 0.6015, 0.1000, 0.7633, 0.5972],
#         [0.6944, 0.2000, 0.2222, 0.2105, 0.2855, 0.6041, 0.7000, 0.7700, 0.5880],
#         [0.5833, 0.2000, 0.2222, 0.1579, 0.2469, 0.6015, 0.2000, 0.7267, 0.6435],
#         [0.7222, 0.2000, 0.2222, 0.1579, 0.2171, 0.6144, 0.2000, 0.6967, 0.6944],
#         [0.6944, 0.1000, 0.1111, 0.1053, 0.2834, 0.6298, 0.0000, 0.5933, 0.7130],
#         [0.4167, 0.1000, 0.1111, 0.0526, 0.3918, 0.6298, 0.0000, 0.5267, 0.6944],
#         [0.4722, 0.1000, 0.1111, 0.0000, 0.4752, 0.6375, 0.0000, 0.5200, 0.6991],
#         [0.4722, 0.1000, 0.1111, 0.0526, 0.5745, 0.6298, 0.0000, 0.5067, 0.6852],
#         [0.5000, 0.1000, 0.1111, 0.1053, 0.5891, 0.6247, 0.0000, 0.5033, 0.6713],
#         [0.0000, 0.0000, 0.1111, 0.0526, 0.5491, 0.6298, 0.0000, 0.5000, 0.6806],
#         [0.4444, 0.1000, 0.1111, 0.0526, 0.5092, 0.6221, 0.0000, 0.5300, 0.6944],
#         [0.4167, 0.2000, 0.1111, 0.0526, 0.3212, 0.6144, 0.0000, 0.5267, 0.6898],
#         [0.3889, 0.1000, 0.2222, 0.1053, 0.2835, 0.6118, 0.0000, 0.5467, 0.6898],
#         [0.5000, 0.1000, 0.1111, 0.0526, 0.4099, 0.6144, 0.0000, 0.5533, 0.7083],
#         [0.5833, 0.2000, 0.2222, 0.1579, 0.4797, 0.6272, 0.0000, 0.6067, 0.7083],
#         [0.6389, 0.2000, 0.2222, 0.2105, 0.5086, 0.6272, 0.0000, 0.6333, 0.6991],
#         [0.6667, 0.4000, 0.3333, 0.2632, 0.4155, 0.6375, 0.0000, 0.6567, 0.6574],
#         [0.6667, 0.4000, 0.4444, 0.3158, 0.3375, 0.6478, 0.1000, 0.6800, 0.6574],
#         [0.6389, 0.3000, 0.3333, 0.3684, 0.2610, 0.6478, 0.1000, 0.7067, 0.6713],
#         [0.5556, 0.4000, 0.4444, 0.2632, 0.2420, 0.6555, 0.3000, 0.7300, 0.6296],
#         [0.5833, 0.4000, 0.4444, 0.3158, 0.2146, 0.6427, 0.2000, 0.7433, 0.5741],
#         [0.5556, 0.3000, 0.3333, 0.2632, 0.1782, 0.6221, 0.1000, 0.7600, 0.5370],
#         [0.5000, 0.4000, 0.4444, 0.2632, 0.1985, 0.6195, 0.0000, 0.7533, 0.5556],
#         [0.5000, 0.5000, 0.4444, 0.3684, 0.2416, 0.5964, 0.0000, 0.7600, 0.6204],
#         [0.5833, 0.5000, 0.4444, 0.4737, 0.2883, 0.5938, 0.0000, 0.7267, 0.5833],
#         [0.5833, 0.4000, 0.7778, 0.5789, 0.2718, 0.6093, 0.0000, 0.5933, 0.6806],
#         [0.5556, 0.2000, 0.3333, 0.3158, 0.1936, 0.5964, 0.0000, 0.5600, 0.7083],
#         [0.4861, 0.1000, 0.1111, 0.1579, 0.2238, 0.5835, 0.0000, 0.5533, 0.7361],
#         [0.4167, 0.2000, 0.2222, 0.1579, 0.2430, 0.5656, 0.0000, 0.5533, 0.7269],
#         [0.3889, 0.2000, 0.2222, 0.1579, 0.3154, 0.5681, 0.0000, 0.5567, 0.7315],
#         [0.4444, 0.3000, 0.2222, 0.1579, 0.2860, 0.5553, 0.0000, 0.5800, 0.7639],
#         [0.5000, 0.3000, 0.3333, 0.2632, 0.2077, 0.5373, 0.0000, 0.5967, 0.7778],
#         [0.5000, 0.2000, 0.2222, 0.2105, 0.1640, 0.5167, 0.0000, 0.6000, 0.7778],
#         [0.4444, 0.3000, 0.3333, 0.2632, 0.1525, 0.4961, 0.0000, 0.5967, 0.7824],
#         [0.4722, 0.4000, 0.3333, 0.3158, 0.1328, 0.4730, 0.0000, 0.6000, 0.7824],
#         [0.5000, 0.4000, 0.4444, 0.3158, 0.1252, 0.4422, 0.0000, 0.6100, 0.7639],
#         [0.4722, 0.2000, 0.3333, 0.2632, 0.1161, 0.4293, 0.0000, 0.6000, 0.7639],
#         [0.4722, 0.2000, 0.2222, 0.1579, 0.1766, 0.4165, 0.0000, 0.5967, 0.7731],
#         [0.5556, 0.4000, 0.3333, 0.3158, 0.2840, 0.4139, 0.0000, 0.6533, 0.8056],
#         [0.5833, 0.5000, 0.4444, 0.4211, 0.3435, 0.4010, 0.5000, 0.6967, 0.8009],
#         [0.5833, 0.6000, 0.5556, 0.4737, 0.3057, 0.3985, 0.0000, 0.6867, 0.8194],
#         [0.5833, 0.6000, 0.5556, 0.4737, 0.2615, 0.4036, 0.0000, 0.6633, 0.8519],
#         [0.6389, 0.5000, 0.6667, 0.5789, 0.2453, 0.4190, 0.0000, 0.6133, 0.7454],
#         [0.6389, 0.7000, 0.7778, 0.6316, 0.1434, 0.4216, 0.6000, 0.7067, 0.6806],
#         [0.6667, 0.9000, 0.8889, 0.7368, 0.1046, 0.4267, 0.7000, 0.7467, 0.6435],
#         [0.6667, 0.8000, 0.7778, 0.7368, 0.0607, 0.4319, 0.8000, 0.7667, 0.6019],
#         [0.6667, 0.9000, 1.0000, 0.8947, 0.0700, 0.4319, 1.0000, 0.7867, 0.6065],
#         [0.6944, 0.8000, 0.8889, 0.7895, 0.0594, 0.4422, 0.4000, 0.7400, 0.6389],
#         [0.6667, 0.8000, 0.7778, 0.6842, 0.0823, 0.4370, 0.5000, 0.7633, 0.6389],
#         [0.6667, 0.7000, 0.8889, 0.7368, 0.1016, 0.4473, 1.0000, 0.7467, 0.6944],
#         [0.6389, 0.9000, 0.8889, 0.8421, 0.1005, 0.4550, 0.5000, 0.7067, 0.5278],
#         [0.6667, 0.7000, 1.0000, 0.8947, 0.0701, 0.4627, 0.3000, 0.6900, 0.5602],
#         [0.6389, 1.0000, 0.8889, 0.9474, 0.0572, 0.4653, 0.0000, 0.6800, 0.5648],
#         [0.6667, 0.9000, 0.8889, 0.8421, 0.0533, 0.4627, 0.0000, 0.6567, 0.5741],
#         [0.6667, 0.7000, 0.7778, 0.7368, 0.0475, 0.4627, 0.0000, 0.6300, 0.6019],
#         [0.6389, 0.4000, 0.5556, 0.5789, 0.0376, 0.4576, 0.0000, 0.6100, 0.6204],
#         [0.6111, 0.5000, 0.4444, 0.4211, 0.0373, 0.4499, 0.0000, 0.5933, 0.6296]])

# %%
train_dataset.pairs[0][1]
# Out:
# tensor([[0.1965],
#         [0.1501],
#         [0.1518],
#         [0.2622],
#         [0.5524],
#         [0.4840],
#         [0.3544],
#         [0.2754],
#         [0.1948],
#         [0.1734],
#         [0.1505],
#         [0.1352],
#         [0.0778],
#         [0.1184],
#         [0.1293],
#         [0.1238],
#         [0.1043],
#         [0.0997],
#         [0.0812],
#         [0.0823],
#         [0.1155],
#         [0.0837],
#         [0.0570],
#         [0.1006]])

# %%
# Assuming train_dataset.u[0] is a pandas Index object with column names
column_names = list(train_dataset.u[0])  # Convert Index to list

# Now, find the indices of the columns 'NO2', 'DD', 'FH'
no2_idx = column_names.index('NO2')
dd_idx = column_names.index('DD')
fh_idx = column_names.index('FH')

print("NO2 index: ", no2_idx)
print("DD index (wind direction): ", dd_idx)
print("FH index (Hourly wind speed): ", fh_idx)
# Out:
# NO2 index:  4
# DD index (wind direction):  0
# FH index (Hourly wind speed):  2

# %%
train_dataset.u[0].iloc[:,no2_idx]
# Out:
# DateTime
# 2017-08-01 00:00:00    0.242115
# 2017-08-01 01:00:00    0.223158
# 2017-08-01 02:00:00    0.165911
# 2017-08-01 03:00:00    0.142363
# 2017-08-01 04:00:00    0.156297
#                          ...
# 2017-11-16 19:00:00    0.523871
# 2017-11-16 20:00:00    0.512314
# 2017-11-16 21:00:00    0.232880
# 2017-11-16 22:00:00    0.108123
# 2017-11-16 23:00:00    0.205120
# Name: NO2, Length: 2592, dtype: float64

# %%
train_dataset.u[0].iloc[:,dd_idx]
# Out:
# DateTime
# 2017-08-01 00:00:00    0.166667
# 2017-08-01 01:00:00    0.000000
# 2017-08-01 02:00:00    0.000000
# 2017-08-01 03:00:00    0.277778
# 2017-08-01 04:00:00    0.805556
#                          ...
# 2017-11-16 19:00:00    0.750000
# 2017-11-16 20:00:00    0.972222
# 2017-11-16 21:00:00    0.888889
# 2017-11-16 22:00:00    0.944444
# 2017-11-16 23:00:00    0.861111
# Name: DD, Length: 2592, dtype: float64

# %%
train_dataset.u[0].iloc[:,fh_idx]
# Out:
# DateTime
# 2017-08-01 00:00:00    0.111111
# 2017-08-01 01:00:00    0.111111
# 2017-08-01 02:00:00    0.000000
# 2017-08-01 03:00:00    0.000000
# 2017-08-01 04:00:00    0.111111
#                          ...
# 2017-11-16 19:00:00    0.333333
# 2017-11-16 20:00:00    0.333333
# 2017-11-16 21:00:00    0.222222
# 2017-11-16 22:00:00    0.111111
# 2017-11-16 23:00:00    0.222222
# Name: FH, Length: 2592, dtype: float64

# %% [markdown]
# ## **Computing y with the y_phy**

# %% [markdown]
# ### **Start hyperparameter searching with Optuna**

# %%
def objective(trial):
    # Define hyperparameters to search over
    n_hidden_layers = trial.suggest_int("n_hidden_layers", 1, 5)
    n_hidden_units = trial.suggest_int("n_hidden_units", 32, 256)
    lr = trial.suggest_loguniform("lr", 1e-5, 1e-2)
    weight_decay = trial.suggest_loguniform("weight_decay", 1e-8, 1e-3)
    batch_size = trial.suggest_categorical("batch_size", [8, 16, 32, 64])  # Match the original hp['batch_sz']
    lambda_phy = trial.suggest_loguniform("lambda_phy", 1e-5, 1e-1)

    # Create train & validation loaders (following the original code)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Initialize MLP model
    model = BasicMLP(
        N_INPUT_UNITS=train_dataset.__n_features_in__(),
        N_HIDDEN_LAYERS=n_hidden_layers,
        N_HIDDEN_UNITS=n_hidden_units,
        N_OUTPUT_UNITS=train_dataset.__n_features_out__(),
        loss_function=LOSS_FUNC,
    )

    # Train and return validation loss
    val_loss = model.train_model(train_loader, val_loader, epochs=50, lr=lr, weight_decay=weight_decay, lambda_phy = lambda_phy, device=device)
    
    return val_loss


# Run Optuna optimization
study = optuna.create_study(direction="minimize", study_name="mlp_hyperparameter_optimization_phy_pde2", storage="sqlite:///mlp_hyperparameter_optimization_phy_pde.db", load_if_exists=True)

study.optimize(objective, n_trials=100)

# Print best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# %%
# best params for the physics model in previous studies
# remove if retune
best_params
# Out:
# {'n_hidden_layers': 2,
#  'n_hidden_units': 248,
#  'lr': 0.008546234469271084,
#  'weight_decay': 5.8109030823582454e-08,
#  'batch_size': 32,
#  'lambda_phy': 0.09838214154627214}

# %%
# Train the model with the best hyperparameters
best_model = BasicMLP(
    N_INPUT_UNITS=train_dataset.__n_features_in__(),
    N_HIDDEN_LAYERS=best_params["n_hidden_layers"],
    N_HIDDEN_UNITS=best_params["n_hidden_units"],
    N_OUTPUT_UNITS=train_dataset.__n_features_out__(),
    loss_function=LOSS_FUNC,
)

# Create train & validation loaders with the best batch size
train_loader = DataLoader(train_dataset, batch_size=best_params["batch_size"], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_params["batch_size"], shuffle=False)

# Train the model
best_model.train_model(train_loader, val_loader, epochs=50, lr=best_params["lr"], weight_decay=best_params["weight_decay"], lambda_phy = best_params['lambda_phy'],device=device)

# Save the trained model
torch.save(best_model.state_dict(), f"{MODEL_PATH}/best_mlp_no2_pde_numerical_eq1.pth")
print("Model saved asbest_mlp_no2_pde_numerical.pth in Model folder")
# Out:
# Epoch 1/50
# Phy loss tensor(0.4074, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1026, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1427, grad_fn=<AddBackward0>)
# Phy loss tensor(0.9331, grad_fn=<MseLossBackward0>)
# MSE loss tensor(1.3599, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(1.4517, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1920, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0338, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0527, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2325, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1457, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1685, grad_fn=<AddBackward0>)
# Epoch 1/50 - Train Loss: 0.453919 - Val Loss (DD rmse only): 0.425437
# Epoch 2/50
# Phy loss tensor(0.3801, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.1058, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1432, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2689, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0985, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1249, grad_fn=<AddBackward0>)
# Phy loss tensor(0.3501, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0879, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.1224, grad_fn=<AddBackward0>)
# Phy loss tensor(0.3610, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0472, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0827, grad_fn=<AddBackward0>)
# Epoch 2/50 - Train Loss: 0.118301 - Val Loss (DD rmse only): 0.283785
# Epoch 3/50
# Phy loss tensor(0.2508, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0332, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0579, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1557, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0331, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0485, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1437, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0437, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0579, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1105, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0549, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0658, grad_fn=<AddBackward0>)
# Epoch 3/50 - Train Loss: 0.057498 - Val Loss (DD rmse only): 0.193952
# Epoch 4/50
# Phy loss tensor(0.1360, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0378, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0512, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1797, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0254, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0431, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1949, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0354, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0545, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1249, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0253, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0376, grad_fn=<AddBackward0>)
# Epoch 4/50 - Train Loss: 0.046573 - Val Loss (DD rmse only): 0.238882
# Epoch 5/50
# Phy loss tensor(0.1352, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0294, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0427, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2486, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0341, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0585, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2240, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0262, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0482, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1845, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0307, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0489, grad_fn=<AddBackward0>)
# Epoch 5/50 - Train Loss: 0.049587 - Val Loss (DD rmse only): 0.188506
# Epoch 6/50
# Phy loss tensor(0.1739, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0222, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0393, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1396, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0257, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0395, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1657, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0271, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0434, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1353, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0310, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0443, grad_fn=<AddBackward0>)
# Epoch 6/50 - Train Loss: 0.041608 - Val Loss (DD rmse only): 0.173526
# Epoch 7/50
# Phy loss tensor(0.1295, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0323, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0450, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1814, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0222, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0401, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1723, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0224, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0393, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0874, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0274, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0360, grad_fn=<AddBackward0>)
# Epoch 7/50 - Train Loss: 0.040103 - Val Loss (DD rmse only): 0.182377
# Epoch 8/50
# Phy loss tensor(0.1545, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0177, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0329, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2126, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0262, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0471, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1842, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0198, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0379, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1626, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0338, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0498, grad_fn=<AddBackward0>)
# Epoch 8/50 - Train Loss: 0.041929 - Val Loss (DD rmse only): 0.169800
# Epoch 9/50
# Phy loss tensor(0.1645, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0171, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0333, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1823, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0201, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0380, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1428, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0226, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0367, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1767, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0354, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0528, grad_fn=<AddBackward0>)
# Epoch 9/50 - Train Loss: 0.040209 - Val Loss (DD rmse only): 0.161540
# Epoch 10/50
# Phy loss tensor(0.1692, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0199, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0366, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1189, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0184, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0301, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2024, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0231, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0430, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1753, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0146, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0319, grad_fn=<AddBackward0>)
# Epoch 10/50 - Train Loss: 0.035393 - Val Loss (DD rmse only): 0.160336
# Epoch 11/50
# Phy loss tensor(0.1696, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0228, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0394, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1916, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0156, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0344, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1673, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0164, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0329, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1408, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0175, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0313, grad_fn=<AddBackward0>)
# Epoch 11/50 - Train Loss: 0.034517 - Val Loss (DD rmse only): 0.153058
# Epoch 12/50
# Phy loss tensor(0.1675, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0151, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0316, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1536, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0197, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0348, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1541, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0198, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0350, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2501, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0153, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0399, grad_fn=<AddBackward0>)
# Epoch 12/50 - Train Loss: 0.035305 - Val Loss (DD rmse only): 0.149355
# Epoch 13/50
# Phy loss tensor(0.1964, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0177, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0370, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1316, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0150, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0279, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1792, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0171, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0347, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1781, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0179, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0354, grad_fn=<AddBackward0>)
# Epoch 13/50 - Train Loss: 0.033761 - Val Loss (DD rmse only): 0.148157
# Epoch 14/50
# Phy loss tensor(0.1630, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0198, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0358, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1617, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0146, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0306, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1881, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0154, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0339, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1453, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0077, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0220, grad_fn=<AddBackward0>)
# Epoch 14/50 - Train Loss: 0.030591 - Val Loss (DD rmse only): 0.142508
# Epoch 15/50
# Phy loss tensor(0.1680, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0140, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0305, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1938, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0140, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1868, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0188, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0372, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0457, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0130, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0175, grad_fn=<AddBackward0>)
# Epoch 15/50 - Train Loss: 0.029587 - Val Loss (DD rmse only): 0.150800
# Epoch 16/50
# Phy loss tensor(0.1698, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0138, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0305, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1458, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0178, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0322, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1806, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0158, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0336, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2254, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0347, grad_fn=<AddBackward0>)
# Epoch 16/50 - Train Loss: 0.032726 - Val Loss (DD rmse only): 0.153036
# Epoch 17/50
# Phy loss tensor(0.1619, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0172, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1552, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0218, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0371, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1464, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0140, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0284, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1782, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0134, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0309, grad_fn=<AddBackward0>)
# Epoch 17/50 - Train Loss: 0.032377 - Val Loss (DD rmse only): 0.139862
# Epoch 18/50
# Phy loss tensor(0.1609, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0162, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0320, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2285, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0154, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0379, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1563, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0159, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0313, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0987, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0106, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0203, grad_fn=<AddBackward0>)
# Epoch 18/50 - Train Loss: 0.030348 - Val Loss (DD rmse only): 0.144944
# Epoch 19/50
# Phy loss tensor(0.1618, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0172, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1647, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0124, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1630, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0164, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0325, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1509, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0232, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0380, grad_fn=<AddBackward0>)
# Epoch 19/50 - Train Loss: 0.033074 - Val Loss (DD rmse only): 0.141600
# Epoch 20/50
# Phy loss tensor(0.1689, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0136, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0302, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1774, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0189, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0364, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1484, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0144, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0290, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1431, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0154, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0295, grad_fn=<AddBackward0>)
# Epoch 20/50 - Train Loss: 0.031270 - Val Loss (DD rmse only): 0.139824
# Epoch 21/50
# Phy loss tensor(0.2002, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0145, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0342, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1507, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0168, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0317, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1410, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0159, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0298, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1530, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0141, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0292, grad_fn=<AddBackward0>)
# Epoch 21/50 - Train Loss: 0.031217 - Val Loss (DD rmse only): 0.137269
# Epoch 22/50
# Phy loss tensor(0.1799, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0136, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0313, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1450, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0176, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0319, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1710, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0150, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0319, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2038, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0087, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0287, grad_fn=<AddBackward0>)
# Epoch 22/50 - Train Loss: 0.030939 - Val Loss (DD rmse only): 0.140208
# Epoch 23/50
# Phy loss tensor(0.1794, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0131, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0307, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1360, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0152, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1862, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0152, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0335, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1539, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0193, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0344, grad_fn=<AddBackward0>)
# Epoch 23/50 - Train Loss: 0.031795 - Val Loss (DD rmse only): 0.144861
# Epoch 24/50
# Phy loss tensor(0.1465, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0180, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0324, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1516, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0165, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0314, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1581, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0156, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0312, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2339, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0095, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0325, grad_fn=<AddBackward0>)
# Epoch 24/50 - Train Loss: 0.031870 - Val Loss (DD rmse only): 0.137031
# Epoch 25/50
# Phy loss tensor(0.1790, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0149, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0325, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1655, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0165, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0327, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1558, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0140, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0293, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1952, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0074, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0266, grad_fn=<AddBackward0>)
# Epoch 25/50 - Train Loss: 0.030291 - Val Loss (DD rmse only): 0.149725
# Epoch 26/50
# Phy loss tensor(0.1363, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0134, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0268, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1840, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0190, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0371, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1260, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0162, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2456, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0174, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0416, grad_fn=<AddBackward0>)
# Epoch 26/50 - Train Loss: 0.033524 - Val Loss (DD rmse only): 0.139334
# Epoch 27/50
# Phy loss tensor(0.1835, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0169, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0349, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1921, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0104, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0293, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1540, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0165, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0317, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1232, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0129, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0250, grad_fn=<AddBackward0>)
# Epoch 27/50 - Train Loss: 0.030247 - Val Loss (DD rmse only): 0.158530
# Epoch 28/50
# Phy loss tensor(0.1445, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0178, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0320, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1296, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0215, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0342, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1924, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0112, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0301, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1644, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0156, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0317, grad_fn=<AddBackward0>)
# Epoch 28/50 - Train Loss: 0.032026 - Val Loss (DD rmse only): 0.142715
# Epoch 29/50
# Phy loss tensor(0.1841, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0129, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0310, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1802, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0148, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0326, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1653, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0153, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0316, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0812, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0160, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0240, grad_fn=<AddBackward0>)
# Epoch 29/50 - Train Loss: 0.029767 - Val Loss (DD rmse only): 0.147458
# Epoch 30/50
# Phy loss tensor(0.1477, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0144, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0289, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1806, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0183, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0361, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1622, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0285, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1556, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0090, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0243, grad_fn=<AddBackward0>)
# Epoch 30/50 - Train Loss: 0.029446 - Val Loss (DD rmse only): 0.139714
# Epoch 31/50
# Phy loss tensor(0.2004, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0169, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0366, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1469, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0146, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0291, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1502, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0131, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0279, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1051, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0188, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0291, grad_fn=<AddBackward0>)
# Epoch 31/50 - Train Loss: 0.030670 - Val Loss (DD rmse only): 0.136891
# Epoch 32/50
# Phy loss tensor(0.1729, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0147, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0318, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1598, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0153, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0310, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1736, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0131, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0302, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1523, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0135, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0285, grad_fn=<AddBackward0>)
# Epoch 32/50 - Train Loss: 0.030383 - Val Loss (DD rmse only): 0.142980
# Epoch 33/50
# Phy loss tensor(0.1506, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0123, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0272, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1514, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0182, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0331, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1627, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0150, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0310, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2124, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0112, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0321, grad_fn=<AddBackward0>)
# Epoch 33/50 - Train Loss: 0.030837 - Val Loss (DD rmse only): 0.141947
# Epoch 34/50
# Phy loss tensor(0.1308, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0116, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0245, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1740, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0121, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0292, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1707, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0192, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0360, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2111, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0146, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0354, grad_fn=<AddBackward0>)
# Epoch 34/50 - Train Loss: 0.031278 - Val Loss (DD rmse only): 0.144464
# Epoch 35/50
# Phy loss tensor(0.2073, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0168, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0372, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1510, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0135, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0284, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1414, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0109, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0248, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0987, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0198, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0295, grad_fn=<AddBackward0>)
# Epoch 35/50 - Train Loss: 0.029976 - Val Loss (DD rmse only): 0.145544
# Epoch 36/50
# Phy loss tensor(0.1727, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0109, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0279, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1731, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0136, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0306, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1447, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0181, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0323, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1389, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0150, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Epoch 36/50 - Train Loss: 0.029876 - Val Loss (DD rmse only): 0.139541
# Epoch 37/50
# Phy loss tensor(0.1859, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0116, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0299, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1572, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0128, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0283, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1541, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0167, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0319, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1680, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0145, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0310, grad_fn=<AddBackward0>)
# Epoch 37/50 - Train Loss: 0.030272 - Val Loss (DD rmse only): 0.144566
# Epoch 38/50
# Phy loss tensor(0.1435, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0131, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0273, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1502, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0131, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0279, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1688, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0161, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0327, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2650, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0159, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0419, grad_fn=<AddBackward0>)
# Epoch 38/50 - Train Loss: 0.032457 - Val Loss (DD rmse only): 0.147672
# Epoch 39/50
# Phy loss tensor(0.1699, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0179, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0346, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1312, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0154, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0283, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1870, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0102, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1099, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0142, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0251, grad_fn=<AddBackward0>)
# Epoch 39/50 - Train Loss: 0.029147 - Val Loss (DD rmse only): 0.142375
# Epoch 40/50
# Phy loss tensor(0.1619, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0149, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0308, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1750, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0297, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1550, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0140, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0292, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1817, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0124, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0303, grad_fn=<AddBackward0>)
# Epoch 40/50 - Train Loss: 0.030017 - Val Loss (DD rmse only): 0.156124
# Epoch 41/50
# Phy loss tensor(0.1523, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0144, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0293, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1407, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0148, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1869, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0128, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0312, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1849, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0135, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0317, grad_fn=<AddBackward0>)
# Epoch 41/50 - Train Loss: 0.030225 - Val Loss (DD rmse only): 0.147108
# Epoch 42/50
# Phy loss tensor(0.1574, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0280, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1766, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0141, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0315, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1420, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0147, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1600, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0149, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0306, grad_fn=<AddBackward0>)
# Epoch 42/50 - Train Loss: 0.029673 - Val Loss (DD rmse only): 0.143359
# Epoch 43/50
# Phy loss tensor(0.1610, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0283, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1587, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0143, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0299, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1583, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0141, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0296, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1947, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0120, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0311, grad_fn=<AddBackward0>)
# Epoch 43/50 - Train Loss: 0.029753 - Val Loss (DD rmse only): 0.157732
# Epoch 44/50
# Phy loss tensor(0.1418, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0183, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0323, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1565, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0133, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0287, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1577, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0142, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0297, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2294, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0083, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0309, grad_fn=<AddBackward0>)
# Epoch 44/50 - Train Loss: 0.030384 - Val Loss (DD rmse only): 0.152607
# Epoch 45/50
# Phy loss tensor(0.1576, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0114, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0269, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1536, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0166, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0317, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1510, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0155, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0303, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1837, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0085, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0265, grad_fn=<AddBackward0>)
# Epoch 45/50 - Train Loss: 0.028855 - Val Loss (DD rmse only): 0.144183
# Epoch 46/50
# Phy loss tensor(0.1320, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0145, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0275, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1431, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0266, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1823, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0125, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0305, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2763, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0149, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0421, grad_fn=<AddBackward0>)
# Epoch 46/50 - Train Loss: 0.031681 - Val Loss (DD rmse only): 0.143591
# Epoch 47/50
# Phy loss tensor(0.1648, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0119, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0281, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1355, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0140, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0274, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1974, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0123, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0317, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1570, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0161, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0315, grad_fn=<AddBackward0>)
# Epoch 47/50 - Train Loss: 0.029670 - Val Loss (DD rmse only): 0.160724
# Epoch 48/50
# Phy loss tensor(0.1279, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0128, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0254, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1481, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0146, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0292, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1797, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0136, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0313, grad_fn=<AddBackward0>)
# Phy loss tensor(0.2422, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0162, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0400, grad_fn=<AddBackward0>)
# Epoch 48/50 - Train Loss: 0.031466 - Val Loss (DD rmse only): 0.159438
# Epoch 49/50
# Phy loss tensor(0.1505, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0155, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0303, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1365, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0155, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0289, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1882, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0148, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0333, grad_fn=<AddBackward0>)
# Phy loss tensor(0.0897, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0109, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0197, grad_fn=<AddBackward0>)
# Epoch 49/50 - Train Loss: 0.028075 - Val Loss (DD rmse only): 0.151726
# Epoch 50/50
# Phy loss tensor(0.1980, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0126, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0320, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1609, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0127, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0286, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1524, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0159, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0309, grad_fn=<AddBackward0>)
# Phy loss tensor(0.1526, grad_fn=<MseLossBackward0>)
# MSE loss tensor(0.0101, grad_fn=<MseLossBackward0>)
# total_weighted_loss tensor(0.0251, grad_fn=<AddBackward0>)
# Epoch 50/50 - Train Loss: 0.029141 - Val Loss (DD rmse only): 0.157419
# Model saved asbest_mlp_no2_pde_numerical.pth in Model folder

# %% [markdown]
# #### **Testing the model**

# %%
df_minmax = pd.read_csv(MINMAX_PATH, sep=';')
df_minmax
# Out:
#   Unnamed: 0   min    max
# 0        NO2  1.37  93.95

# %%
best_model.load_state_dict(torch.load(f"{MODEL_PATH}/best_mlp_no2_pde_numerical_eq1.pth"))
best_model.eval()

# Create the DataLoader for the test dataset
test_loader = DataLoader(test_dataset, batch_size=best_params["batch_size"], shuffle=False)

# Evaluate the model on the test dataset
df_minmax = pd.read_csv(MINMAX_PATH, sep=';')
min_value = df_minmax["min"].values
max_value = df_minmax["max"].values
mse, rmse_val, smape_val = best_model.test_model(test_loader, min_value=min_value, max_value=max_value, device="cpu")
# Out:
# Test MSE Loss: 246.429704
# Test RMSE Loss: 15.698080
# Test SMAPE Loss: 42.152271%

# %%
print(f"Test MSE: {mse}, Test RMSE: {rmse_val}, Test SMAPE: {smape_val}")
# Out:
# Test MSE: 246.42970379886606, Test RMSE: 15.698079621369809, Test SMAPE: 42.152270564326535

# %%
import torch
import matplotlib.pyplot as plt

# Ensure the model is in evaluation mode
best_model.eval()

y_preds = []
y_trues = []

# Iterate through the test set and collect predictions & ground truth
with torch.no_grad():
    for batch in test_loader:
        x_test, y_true = batch  # Get input and ground truth
        x_test = x_test.to("cpu")  # Ensure data is on CPU if needed

        # Get predictions
        y_pred = best_model(x_test)

        # Store results
        y_preds.append(y_pred.cpu())
        y_trues.append(y_true.cpu())

# Convert lists to tensors
y_preds = torch.cat(y_preds, dim=0).numpy()
y_trues = torch.cat(y_trues, dim=0).numpy()

# Plot results
plt.figure(figsize=(10, 5))
plt.plot(y_trues.flatten(), label="Ground Truth (NO₂)", linestyle="-", color="blue")
plt.scatter(range(len(y_preds.flatten())), y_preds.flatten(), label="Predictions", color="black", s=10)

plt.xlabel("Time Step")
plt.ylabel("NO₂ Level")
plt.title("Predictions vs. Ground Truth")
plt.legend()
plt.show()
